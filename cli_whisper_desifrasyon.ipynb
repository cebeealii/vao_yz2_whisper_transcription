# %% [markdown]
# <a href="https://colab.research.google.com/github/cebeealii/vao_yz2_whisper_transcription/blob/main/cli_whisper_desifrasyon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q openai-whisper
# !apt update && apt install -y ffmpeg

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !whisper vao_ders_kisa.m4a --language Turkish --model small
